# %% [markdown]
# # Agent

# %%
import sys, os

# If you're running inside Back/Agents/... in a notebook
PROJECT_ROOT = os.path.abspath(os.path.join(os.getcwd(), ".."))  # go up one level to Back/
sys.path.insert(0, PROJECT_ROOT)

print("PROJECT_ROOT:", PROJECT_ROOT)
# Out:
# PROJECT_ROOT: /Users/joseandres/Library/CloudStorage/OneDrive-ScientificNetworkSouthTyrol/Thesis/Thesis-labs/System/Back

# %%
from Assistant.ChatAssistant import ChatAssistant

agent = ChatAssistant()
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 from Assistant.ChatAssistant import ChatAssistant
#       3 agent = ChatAssistant()
#
# File ~/Library/CloudStorage/OneDrive-ScientificNetworkSouthTyrol/Thesis/Thesis-labs/System/Back/Agents/Assistant/ChatAssistant.py:4
#       2 import uuid
#       3 import logging
# ----> 4 from .Agent import Agent
#       5 from app.db.init import init_db
#       6 from app.db.session import SessionLocal
#
# File ~/Library/CloudStorage/OneDrive-ScientificNetworkSouthTyrol/Thesis/Thesis-labs/System/Back/Agents/Assistant/Agent.py:19
#      17 from utils.utils import Settings, load_prompt
#      18 logger = logging.getLogger(__name__)
# ---> 19 from app.models.log import Log
#      20 from app.models.agentRun import AgentRun
#      21 from app.models.message import Message
#
# File ~/Library/CloudStorage/OneDrive-ScientificNetworkSouthTyrol/Thesis/Thesis-labs/System/Back/app/models/__init__.py:12
#       9 from .log import Log
#      11 # NEW:
# ---> 12 from .experiments import (
#      13     Experiment, ExperimentRun, EvaluationDataset, RunItem,
#      14     PlanningGpt4Eval, TaskEval, AgentRunFeedback, InterpretabilityRating,
#      15     UsefulnessRating, DecisionSupportMetric, SusSurvey
#      16 )
#      18 __all__ = [
#      19     "User", "UserSession", "AgentRun", "AgentStep", "Message", "ToolCall", "LLMCall", "Log", "EvaluationDataset",
#      20     "Experiment", "ExperimentRun", "RunItem",
#      21     "PlanningGpt4Eval", "TaskEval", "AgentRunFeedback", "InterpretabilityRating",
#      22     "UsefulnessRating", "DecisionSupportMetric", "SusSurvey",
#      23 ]
#
# ImportError: cannot import name 'EvaluationDataset' from 'app.models.experiments' (/Users/joseandres/Library/CloudStorage/OneDrive-ScientificNetworkSouthTyrol/Thesis/Thesis-labs/System/Back/app/models/experiments.py)

# %%
agent.ask("forecast the data to 2030 using the tools")

# %%
agent.ask("forecast the data to 2050 using the tools")

# %%
agent.ask("forecast the data to 2090 using the tools")

# %% [markdown]
# # System Evaluation

# %%
from Evaluation.AgentEval import AgentEval

agentEval = AgentEval()

# %%
agentEval.eval()

# %%
from sqlalchemy import inspect
from app.db.session import engine, SessionLocal
from app.db.init import init_db
from app.db.base import Base
import app.models

init_db()

print("Metadata tables:", sorted(Base.metadata.tables.keys()))
insp = inspect(engine)
print("DB tables:", insp.get_table_names())

with SessionLocal() as db:
    print("Connected to:", db.get_bind().url)

# %% [markdown]
# # Agent

# %%
import sys, os

# If you're running inside Back/Agents/... in a notebook
PROJECT_ROOT = os.path.abspath(os.path.join(os.getcwd(), ".."))  # go up one level to Back/
sys.path.insert(0, PROJECT_ROOT)

print("PROJECT_ROOT:", PROJECT_ROOT)
# Out:
# PROJECT_ROOT: /Users/joseandres/Library/CloudStorage/OneDrive-ScientificNetworkSouthTyrol/Thesis/Thesis-labs/System/Back

# %%
from Assistant.ChatAssistant import ChatAssistant

agent = ChatAssistant()
# Out:
# /Users/joseandres/Library/CloudStorage/OneDrive-ScientificNetworkSouthTyrol/Thesis/Thesis-labs/System/Back/Agents/Assistant/Agent.py:109: LangChainDeprecationWarning: Please see the migration guide at: https://python.langchain.com/docs/versions/migrating_memory/
#   memory = ConversationBufferMemory(return_messages=True)
# /Users/joseandres/Library/CloudStorage/OneDrive-ScientificNetworkSouthTyrol/Thesis/Thesis-labs/System/Back/Agents/Assistant/Agent.py:110: LangChainDeprecationWarning: The class `ConversationChain` was deprecated in LangChain 0.2.7 and will be removed in 1.0. Use :class:`~langchain_core.runnables.history.RunnableWithMessageHistory` instead.
#   self.llm = ConversationChain(llm=base_llm, memory=memory, verbose=False)

# %%
agent.ask("forecast the data to 2030 using the tools")
# Out:
# ['predict_population_linear', 'predict_population_linear']
# items 1 order 1 total 2
# I can forecast population data up to 2030 for you.
#
# To achieve this, I used a combination of linear regression models and historical population data. Here's an overview of the process:
#
# First, I applied a linear regression model to predict the population trend from 2023 to 2030. This was done by analyzing various factors such as fertility rates, mortality rates, urbanization, and economic growth. The data used for this analysis included historical population counts, demographic statistics, and socio-economic indicators.
#
# Next, I predicted the population in each year from 2024 to 2030 using the linear regression model. For the years 2029 and 2030, I specifically ran two separate tasks: 'predict_population_linear' for both years. The task used a different set of parameters to account for potential fluctuations in population growth rates.
#
# For the prediction results, I obtained the following outputs:
#
# - Population forecasted for 2029: 4058
# - Population forecasted for 2030: 4060
#
# These predictions are based on the analysis and model inference results provided above.

# %%
agent.ask("forecast the data to 2050 using the tools")

# %%
agent.ask("forecast the data to 2090 using the tools")

# %%
from sqlalchemy import inspect
from app.db.session import engine, SessionLocal
from app.db.init import init_db
from app.db.base import Base
import app.models

init_db()

print("Metadata tables:", sorted(Base.metadata.tables.keys()))
insp = inspect(engine)
print("DB tables:", insp.get_table_names())

with SessionLocal() as db:
    print("Connected to:", db.get_bind().url)
